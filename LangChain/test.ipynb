# %%
from my_llm import llm

resp = llm.invoke('用三句话简单介绍一下：机器学习的基本概念')
print(type(resp))
print(resp)
# Out:
# 你好！我是一个人工智能助手。我可以帮你回答问题、提供信息、翻译文本、协助写作，或者陪你聊天。请问今天有什么我可以帮你的吗？
# <class 'langchain_core.messages.ai.AIMessage'>
# ...
